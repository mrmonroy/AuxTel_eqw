# %%
import numpy as np
from astropy.io import fits
import matplotlib.pyplot as plt
from astropy.visualization import (MinMaxInterval,SqrtStretch,ZScaleInterval,PercentileInterval,ImageNormalize)
from astropy.visualization.stretch import SinhStretch, LinearStretch,AsinhStretch,LogStretch
from itertools import repeat
from matplotlib.colors import LogNorm
import os
import pandas as pd
from scipy.optimize import curve_fit

# %%
def plot_image(ff):
    for seg in range(1,num_segments+1):
        #print(seg,ff[seg].header['EXTNAME'])
        if seg<9:
            data_ = ff[seg].data[:shape0[0]-voverscan,hprescan:shape0[1]-hoverscan]
            data_ = np.flip(data_,axis=0)
            data_ = np.flip(data_,axis=1)
            if seg==1:
                dred0 = data_
            else:
                dred0 = np.concatenate((dred0,data_),axis=1)
        else:
            seg_ = num_segments+9-seg
            data_ = ff[seg_].data[:shape0[0]-voverscan,hprescan:shape0[1]-hoverscan]
            #data_ = np.flip(data_,axis=0)
            data_ = np.flip(data_,axis=1)
            if seg_==16:
                dred1 = data_
            else:
                dred1 = np.concatenate((dred1,data_),axis=1)
    data_image = np.concatenate((dred1,dred0),axis=0)
    return data_image

# %%
def fun_fit(x,a,b,c,d):
    return a*x**3.+b*x**2.+c*x+d

# %%
'''
def fun_fit(x,a,b,c,d,e):
    return a*x**4.+b*x**3.+c*x**2.+d*x+e
'''
# Out:
# '\ndef fun_fit(x,a,b,c,d,e):\n    return a*x**4.+b*x**3.+c*x**2.+d*x+e\n'

# %%
'''
def fun_fit(x,a,b,c,d,e,f,g,h):
    return a*x**7.+b*x**6.+c*x**5.+d*x**4.+e*x**3.+f*x**2.+g*x+h
'''
# Out:
# '\ndef fun_fit(x,a,b,c,d,e,f,g,h):\n    return a*x**7.+b*x**6.+c*x**5.+d*x**4.+e*x**3.+f*x**2.+g*x+h\n'

# %%
source_spec = 'ETA1DOR'
spec_date = '2022-03-16'
flat_filter = 'FELH0600'
date_deflattening = '20220608'
opt_setting = 'empty_holo4_003'

# %%
#spec0_path = '/sps/lsst/groups/auxtel/data/raw_ncsa/{0}/{1}/'

if spec_date.replace('-','')==spec_date:
    #spec0_path = '/sps/lsst/groups/auxtel/data/raw_ncsa/{0}/{1}/'
    old_date = False
else:
    #spec0_path = '/sps/lsst/groups/auxtel/data/raw_ncsa/{0}/'
    old_date = True
    
specdb_path = 'output_fits/deflatten_spectra_{0}_{1}_{2}_{3}_bias_{3}/'
specdf_path = 'output_fits/deflatten_spectra_{0}_{1}_{2}_{3}_bias_{3}/'

# %%
spec_list_path = 'output_lists/spectra_by_source/{0}_{1}/'
spec_list_label = 'image_list_{0}_{1}.txt'
'''
if old_date:
    spec0_label = 'AT_O_{0}_{1}-R00S00.fits'
else:
    spec0_label = 'AT_O_{0}_{1}_R00_S00.fits'
'''
specdb_label = 'AT_O_{0}_{1}_R00_S00_debias.fits'
specdf_label = 'AT_O_{0}_{1}_R00_S00_deflatten.fits'

# %%
num_segments = 16
shape0 = (2048,576)
shapef = (4000,4072)
hprescan = 3
hoverscan = 64
voverscan = 48

# %%
t_exp = 30
Seff = 1.06*10000.
print(1./(t_exp*Seff))
# Out:
# 3.1446540880503146e-06

# %%
pixnm = 1./2.73 #nm/pix (from Marc's notes)

# %%
#coord_spec = (1670,1840)

# %%
table_file = os.path.join(spec_list_path.format(spec_date.replace('-',''),opt_setting),spec_list_label.format(spec_date.replace('-',''),opt_setting))
spec_table = pd.read_table(table_file,delimiter='\t',names=['seqNum','dayObs','filter','disperser','source','path'])

# %%
source_mask = list(map(lambda x: source_spec in x, spec_table['source'][1:]))
source_mask = np.array(source_mask)

# %%
spec_seqn = np.array(spec_table['seqNum'][1:][source_mask])

# %%
spec_seqn
# Out:
# array(['000330 ', '000331 ', '000337 ', '000338 ', '000344 ', '000345 ',
#        '000372 ', '000373 ', '000379 ', '000380 ', '000386 ', '000387 ',
#        '000400 ', '000401 '], dtype=object)

# %%
seqn_ref = spec_seqn[0].strip()

if old_date:
    fref = fits.open(os.path.join(specdb_path.format(spec_date.replace('-',''),source_spec,flat_filter,date_deflattening,date_deflattening),specdb_label.format(spec_date.replace('-',''),seqn_ref)))
else:
    fref = fits.open(os.path.join(specdb_path.format(spec_date.replace('-',''),source_spec,flat_filter,date_deflattening,date_deflattening),specdb_label.format(spec_date.replace('-',''),seqn_ref)))

# %%
dataref = plot_image(fref)

# %%
fig = plt.figure(figsize=(14,14))
ax=fig.add_subplot(111)
im = ax.imshow(dataref,cmap="gray",vmin=12000,vmax=18000)#,norm=LogNorm())
fig.colorbar(im,ax=ax)
plt.xlim(1500,2000)
#plt.ylim(200,3500)
plt.axvline(x=1742)

# %%
x_spec = 1742

# %%
specdb_dict = {}
specdf_dict = {}

for seqn in spec_seqn[:1]:
    seqn = seqn.strip()
    print(seqn)
    '''
    if old_date:
        fdb = fits.open(os.path.join(specdb_path.format(spec_date,seqn),spec0_label.format(spec_date.replace('-',''),seqn)))
    else:
        fdb = fits.open(os.path.join(specdb_path.format(spec_date,seqn),specdb_label.format(spec_date,seqn)))
    '''
    fdb = fits.open(os.path.join(specdb_path.format(spec_date.replace('-',''),source_spec,flat_filter,date_deflattening,date_deflattening),specdb_label.format(spec_date.replace('-',''),seqn)))
    fdf = fits.open(os.path.join(specdf_path.format(spec_date.replace('-',''),source_spec,flat_filter,date_deflattening,date_deflattening),specdf_label.format(spec_date.replace('-',''),seqn)))
    assert source_spec in fdb[0].header['OBJECT']
    assert source_spec in fdf[0].header['OBJECT']
    
    imagedb = plot_image(fdb)
    imagedf = plot_image(fdf)
    
    assert imagedb.shape==shapef
    assert imagedf.shape==shapef
    
    #spec0 = image0[:,coord_spec[0]:coord_spec[1]]
    #spec0_sum = np.sum(spec0,axis=1)
    specdb = imagedb[:,x_spec]
    
    #specdf = imagedf[:,coord_spec[0]:coord_spec[1]]
    #specdf_sum = np.sum(specdf,axis=1)
    specdf = imagedf[:,x_spec]
    
    assert fdb[0].header['AMSTART']==fdf[0].header['AMSTART']
    assert fdb[0].header['AMEND']==fdf[0].header['AMEND']
    
    am_start = fdb[0].header['AMSTART']
    am_end = fdb[0].header['AMEND']
    
    am = np.mean([am_start,am_end])
    
    #spec0_dict[seqn] = (am,spec0_sum)
    #specdf_dict[seqn] = (am,specdf_sum)
    
    specdb_dict[seqn] = (am,specdb)
    specdf_dict[seqn] = (am,specdf)
# Out:
# 000330

# %%
fig = plt.figure(figsize=(16,10))
ax1=fig.add_subplot(121)
plt.grid()
#plt.ylim((2.0e6,3.0e6))
ax2=fig.add_subplot(122)
plt.grid()
#plt.ylim((0.,1.0e6))
for seqn in spec_seqn:
    seqn = seqn.strip()
    ax1.plot(np.arange(shapef[0]),specdb_dict[seqn][1],alpha=0.3)
    
    ax2.plot(np.arange(shapef[0]),specdf_dict[seqn][1],alpha=0.3)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_8276/170252386.py in <module>
#       8 for seqn in spec_seqn:
#       9     seqn = seqn.strip()
# ---> 10     ax1.plot(np.arange(shapef[0]),specdb_dict[seqn][1],alpha=0.3)
#      11
#      12     ax2.plot(np.arange(shapef[0]),specdf_dict[seqn][1],alpha=0.3)
#
# KeyError: '000331'

# %%
fig = plt.figure(figsize=(14,10))
ax1=fig.add_subplot(121)
plt.grid()
#plt.ylim((2.0e6,3.0e6))
ax2=fig.add_subplot(122)
plt.grid()
#plt.ylim((0.,1.0e6))
for seqn in spec_seqn:
    seqn = seqn.strip()
    ax1.plot(np.arange(shapef[0]),specdb_dict[seqn][1],alpha=0.3)
    ax1.set_xlim(1200,4000)
    ax1.set_ylim(0,40000)
    
    ax2.plot(np.arange(shapef[0]),specdf_dict[seqn][1],alpha=0.3)
    ax2.set_xlim(1200,4000)
    ax2.set_ylim(0,40000)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_8276/1697641785.py in <module>
#       8 for seqn in spec_seqn:
#       9     seqn = seqn.strip()
# ---> 10     ax1.plot(np.arange(shapef[0]),specdb_dict[seqn][1],alpha=0.3)
#      11     ax1.set_xlim(1200,4000)
#      12     ax1.set_ylim(0,40000)
#
# KeyError: '000331'

# %%
x_pix = np.arange(shapef[0])
x_ = x_pix*pixnm

# %%
#Show one spectrum to define integration region around a line 
specdf_ref = specdf_dict[spec_seqn[0].strip()][1]/(t_exp*Seff)
fig = plt.figure(figsize=(16,10))
plt.plot(x_pix,specdf_ref)
plt.grid()
#plt.ylim((0.,0.2e6))
plt.ylim((0.,0.25))
# Out:
# (0.0, 0.25)

# %%
#Select a very narrow range around the line
fig = plt.figure(figsize=(16,10))
plt.plot(x_pix,specdf_ref)
plt.grid()
#plt.ylim((0.,0.2e6))
plt.ylim((0.,0.25))
#plt.xlim((1650,1700))
xmin0pix = 2150
xmax0pix = 2200
xmin0 = xmin0pix*pixnm
xmax0 = xmax0pix*pixnm
plt.xlim(xmin0pix-200,xmax0pix+200)
plt.axvline(x=xmin0pix,ls='--',color='r')
plt.axvline(x=xmax0pix,ls='--',color='r')

# %%
xminpix_line = np.where(specdf_ref==np.min(specdf_ref[xmin0pix:xmax0pix]))[0]
xmin_line = xminpix_line*pixnm
fmin_line = specdf_ref[xminpix_line][0]
print(xminpix_line,fmin_line)
# Out:
# [2174] 0.05690052924659599

# %%
#Interval for the continuum (to fit the continuum) 
xmin_c = 2125*pixnm
xmax_c = 2230*pixnm

#Interval to integrate (narrower region than for the continuum) 
xmin_int = xmin0pix*pixnm
xmax_int = xmax0pix*pixnm

# %%
fig = plt.figure(figsize=(16,10))
plt.plot(x_pix,specdf_ref)
plt.grid()
#plt.ylim((0.,0.2e6))
plt.ylim((0.,0.25))
plt.xlim((2100,2280))
#plt.ylim(75000,90000)
plt.axvline(x=xmin_c/pixnm,ls='--',color='r')
plt.axvline(x=xmax_c/pixnm,ls='--',color='r')
plt.axvline(x=xmin_int/pixnm,ls='--',color='b')
plt.axvline(x=xmax_int/pixnm,ls='--',color='b')

# %%
fig = plt.figure(figsize=(16,10))
plt.plot(x_,specdf_ref)
plt.grid()
#plt.ylim((0.,0.2e6))
plt.ylim((0.,0.25))
plt.axvline(x=xmin_c,ls='--',color='r')
plt.axvline(x=xmax_c,ls='--',color='r')
plt.axvline(x=xmin_int,ls='--',color='b')
plt.axvline(x=xmax_int,ls='--',color='b')
plt.xlabel(r'$\lambda \, [nm]$',fontsize=14)
plt.ylabel(r'$\gamma / (s \cdot cm^2 \cdot nm$)',fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.savefig('output_plots/eqw_line_fit_{0}/'.format(source_spec)+'spec_{0}_eqw_line.png'.format(source_spec))

# %%
xmask_c = (x_>=xmin_c)*(x_<=xmax_c)

# %%
def eqw(x,flux,xmask,min_int,max_int,xmin_line,return_fit=False,make_plot=True,plot_name='test.png'): 
    xline = x[xmask]
    fline = flux[xmask]
    
    xc1 = xline[xline<=min_int]
    yc1 = fline[xline<=min_int]

    xc2 = xline[xline>=max_int]
    yc2 = fline[xline>=max_int]
    
    xc3 = np.concatenate((xc1,xc2))
    yc3 = np.concatenate((yc1,yc2))
    
    p3,cov3 = curve_fit(fun_fit,xc3,yc3)
        
    linemask = (xline>=min_int)*(xline<=max_int)
    xline_model = xline[linemask]
    fline_model = fun_fit(xline_model,p3[0],p3[1],p3[2],p3[3])
    #fline_model = fun_fit(xline_model,p3[0],p3[1],p3[2],p3[3],p3[4])
    #fline_model = fun_fit(xline_model,p3[0],p3[1],p3[2],p3[3],p3[4],p3[5],p3[6],p3[7])
    
    area_c = np.trapz(fline_model,xline_model)
    area_ul = np.trapz(fline[linemask],xline_model)
    
    area_l = area_c-area_ul
    #print(area_c)
    #print(area_ul)
    #print(area_l)
    
    cont_min = fun_fit(xmin_line,p3[0],p3[1],p3[2],p3[3])[0]
    #cont_min = fun_fit(xmin_line,p3[0],p3[1],p3[2],p3[3],p3[4])[0]
    #cont_min = fun_fit(xmin_line,p3[0],p3[1],p3[2],p3[3],p3[4],p3[5],p3[6],p3[7])[0]
    #print(cont_min)
    
    eqw = area_l/cont_min
    #print('EQW = ',eqw)
    
    eqwmask = (xline>=xmin_line-eqw/2.)*(xline<=xmin_line+eqw/2.)
    continuum = np.ones(len(fline[eqwmask]))*cont_min
    #print(continuum)
    #print(xmin_line-eqw/2.,xmin_line+eqw/2.)
    
    #print(len(xline_model))
    #print(len(fun_fit(xline_model,p3[0],p3[1],p3[2],p3[3])))
    #print(len(fun_fit(xline_model,p3[0],p3[1],p3[2],p3[3],p3[4])))
    #print(len(fun_fit(xline_model,p3[0],p3[1],p3[2],p3[3],p3[4],p3[5],p3[6],p3[7])))
    #print(len(fline[linemask]))
    
    if make_plot:
        fig=plt.figure(figsize=(10,6))
        plt.plot(xline,fline)
        plt.plot(xline,fun_fit(xline,p3[0],p3[1],p3[2],p3[3]),ls='--',color='orange')
        #plt.plot(xline,fun_fit(xline,p3[0],p3[1],p3[2],p3[3],p3[4]),ls='--',color='orange')
        #plt.plot(xline,fun_fit(xline,p3[0],p3[1],p3[2],p3[3],p3[4],p3[5],p3[6],p3[7]),ls='--',color='orange')
        plt.fill_between(xline_model,fun_fit(xline_model,p3[0],p3[1],p3[2],p3[3]),fline[linemask],color='gray',alpha=0.2)
        #plt.fill_between(xline_model,fun_fit(xline_model,p3[0],p3[1],p3[2],p3[3],p3[4]),fline[linemask],color='gray',alpha=0.2)
        #plt.fill_between(xline_model,fline_model,fline[linemask],color='gray',alpha=0.2)
        plt.fill_between(xline[eqwmask],continuum,color='cyan',alpha=0.2)
        #plt.ylim(0.20,0.30)
        #plt.ylim(70000,90000)
        plt.xlabel(r'$\lambda \, [nm]$',fontsize=12)
        plt.ylabel(r'$\gamma \, / \, (s \cdot cm^2 \cdot nm)$',fontsize=12)
        plt.grid()
        plot_outdir = 'output_plots/eqw_line_fit_{0}/'.format(source_spec)
        if os.path.exists(plot_outdir)==False:
            os.mkdir(plot_outdir)
        plt.savefig(plot_outdir+plot_name) 
    
    if return_fit:
        return eqw, p3, xline, fline, fun_fit(xline,p3[0],p3[1],p3[2],p3[3]) #fun_fit(xline,p3[0],p3[1],p3[2],p3[3],p3[4]) #fun_fit(xline,p3[0],p3[1],p3[2],p3[3],p3[4],p3[5],p3[6],p3[7])
    else:
        return eqw

# %%
#eqw, params, x, fl = eqw(x_,specdf_ref,xmask_c,xmin_int,xmax_int,xmin_line)
eqw_val = eqw(x_,specdf_ref,xmask_c,xmin_int,xmax_int,xmin_line)

# %%
eqw_val
# Out:
# 1.2800741211907716

# %%
specdb_ref = specdb_dict[spec_seqn[0].strip()][1]/(t_exp*Seff)
eqw_val_bias = eqw(x_,specdb_ref,xmask_c,xmin_int,xmax_int,xmin_line)

# %%
eqw_val_bias
# Out:
# 1.3511109441430327

# %% [markdown]
# # Iterate over all available images (both with and without flat-fielding)

# %%
airmass = []
eqwdb = []
eqwdf = []
for seqn in spec_seqn:
    seqn = seqn.strip()
    fluxdb = specdb_dict[seqn][1]/(t_exp*Seff)
    fluxdf = specdf_dict[seqn][1]/(t_exp*Seff)
    airmass_ = specdb_dict[seqn][0]
    
    eqwdb_ = eqw(x_,fluxdb,xmask_c,xmin_int,xmax_int,xmin_line,make_plot=False)
    eqwdf_ = eqw(x_,fluxdf,xmask_c,xmin_int,xmax_int,xmin_line,make_plot=False)
    
    if eqwdb_<0.:
        print(seqn)
        plot_name_ = 'fit_line_{0}_eqw0.png'.format(seqn)
        eqwdb_ = eqw(x_,flux0,xmask_c,xmin_int,xmax_int,xmin_line,make_plot=True,plot_name=plot_name_)
    elif eqwdf_<0.:
        print(seqn)
        plot_name_ = 'fit_line_{0}_eqwdf.png'.format(seqn)
        eqwdf_ = eqw(x_,fluxdf,xmask_c,xmin_int,xmax_int,xmin_line,make_plot=True,plot_name=plot_name_)
    '''
    plot_name_ = 'fit_line_{0}_eqw0.png'.format(seqn)
    eqw0_ = eqw(x_,flux0,xmask_c,xmin_int,xmax_int,xmin_line,make_plot=True,plot_name=plot_name_)
    
    plot_name_ = 'fit_line_{0}_eqwdf.png'.format(seqn)
    eqwdf_ = eqw(x_,fluxdf,xmask_c,xmin_int,xmax_int,xmin_line,make_plot=True,plot_name=plot_name_)
    '''
    airmass.append(airmass_)
    eqwdb.append(eqwdb_)
    eqwdf.append(eqwdf_)
airmass = np.array(airmass)
eqwdb = np.array(eqwdb)
eqwdf = np.array(eqwdf)

# %%
fig=plt.figure(figsize=(10,6))
plt.plot(airmass,eqwdb,ls='',marker='o',color='b',label='raw-bias')
plt.plot(airmass,eqwdf,ls='',marker='o',color='orange',label='(raw-bias)/flat')
plt.grid()
plt.xlabel('airmass',fontsize=12)
plt.ylabel('EQW [nm]',fontsize=12)
plt.title('{0}'.format(source_spec),fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.legend(fontsize=14)
plt.savefig('output_plots/eqw_line_fit_{0}/'.format(source_spec)+'eqw_airmass_{0}.png'.format(source_spec))

# %%
np.std(eqwdb)
# Out:
# 0.07510982765053728

# %%
np.std(eqwdf)
# Out:
# 0.07595011786703394

# %%
eqwdb, p3db, xlinedb, flinedb, fmodeldb = eqw(x_,specdb_dict['000330'][1],xmask_c,xmin_int,xmax_int,xmin_line,return_fit=True,make_plot=False)

# %%
eqwdf, p3df, xlinedf, flinedf, fmodeldf = eqw(x_,specdf_dict['000330'][1],xmask_c,xmin_int,xmax_int,xmin_line,return_fit=True,make_plot=False)

# %%
plt.plot(xlinedb,flinedb/(t_exp*Seff),color='b')
plt.plot(xlinedf,flinedf/(t_exp*Seff),color='r')
plt.grid()

# %%
spec_seqn[0]
# Out:
# '000330 '

# %%
f0 = fits.open('/sps/lsst/groups/auxtel/data/raw_ncsa/20220630/000076/AT_O_20220630_000076_R00_S00.fits')

# %%
f0[0].header
# Out:
# SIMPLE  =                    T / Java FITS: Tue Jun 28 16:59:07 UTC 2022
# BITPIX  =                    8 / bits per data value
# NAXIS   =                    0 / number of axes
# EXTEND  =                    T / Extensions are permitted
# DATE    = '2022-06-30T23:36:20.957' / Creation Date and Time of File
# MJD     =    59760.98357589124 / Modified Julian Date that the file was written
# CCD_MANU= 'ITL     '           / CCD Manufacturer
# CCD_TYPE= '3800C   '           / CCD Model Number
# TESTTYPE= 'OBJECT' / BIAS, DARK, FE55, FLAT, LAMBDA, PERSISTENCE, SPOT, SFLAT_<l
# IMGTYPE = 'OBJECT  '           / BIAS, DARK, FE55, FLAT, FLAT_<lam>, SPOT, PPUMP
# DETSIZE = '[1:4072,1:4000]'
# TEMP_SET=               -94.15 / CCD Temperature set point (deg C)
# EXPTIME =                 30.0 / Exposure Time in Seconds
# FILENAME= 'AT_O_20220630_000076_R00_S00.fits' / Original name of the file
# BINX    =                    1 / [pixels] binning along X axis
# ...

# %%
for seg in range(1,num_segments+1):
    print(seg,f0[seg].header['EXTNAME'])
    if seg<9:
        data_ = f0[seg].data
        data_ = np.flip(data_,axis=0)
        data_ = np.flip(data_,axis=1)
        if seg==1:
            dspec0 = data_
        else:
            dspec0 = np.concatenate((dspec0,data_),axis=1)
    else:
        seg_ = num_segments+9-seg
        data_ = f0[seg_].data
        data_ = np.flip(data_,axis=1)
        if seg_==16:
            dspec1 = data_
        else:
            dspec1 = np.concatenate((dspec1,data_),axis=1)
data_spec00 = np.concatenate((dspec1,dspec0),axis=0)
# Out:
# 1 Segment10
# 2 Segment11
# 3 Segment12
# 4 Segment13
# 5 Segment14
# 6 Segment15
# 7 Segment16
# 8 Segment17
# 9 Segment07
# 10 Segment06
# 11 Segment05
# 12 Segment04
# 13 Segment03
# 14 Segment02
# 15 Segment01
# 16 Segment00

# %%
data_spec00.shape
# Out:
# (4096, 4608)

# %%
_ = plt.hist(data_spec00.ravel(),bins=100)
plt.yscale("log")

# %%
fig = plt.figure(figsize=(15,15))
ax=fig.add_subplot(111)
im = ax.imshow(data_spec00,cmap="gray",vmin=12000,vmax=16000)#,norm=LogNorm())
fig.colorbar(im,ax=ax)

# %%
transform = AsinhStretch() + PercentileInterval(99.)
scaledImage00=transform(data_spec00)
fig = plt.figure(figsize=(10,10))
ax=fig.add_subplot(111)
im = ax.imshow(scaledImage00,origin="upper")
fig.colorbar(im,ax=ax)

# %%
data_spec0_test = plot_image(f0)
# Out:
# 1 Segment10
# 2 Segment11
# 3 Segment12
# 4 Segment13
# 5 Segment14
# 6 Segment15
# 7 Segment16
# 8 Segment17
# 9 Segment07
# 10 Segment06
# 11 Segment05
# 12 Segment04
# 13 Segment03
# 14 Segment02
# 15 Segment01
# 16 Segment00

# %%
for seg in range(1,num_segments+1):
    print(seg,f0[seg].header['EXTNAME'])
    if seg<9:
        data_ = f0[seg].data[:shape0[0]-voverscan,hprescan:shape0[1]-hoverscan]
        data_ = np.flip(data_,axis=0)
        data_ = np.flip(data_,axis=1)
        if seg==1:
            dspec0 = data_
        else:
            dspec0 = np.concatenate((dspec0,data_),axis=1)
    else:
        seg_ = num_segments+9-seg
        data_ = f0[seg_].data[:shape0[0]-voverscan,hprescan:shape0[1]-hoverscan]
        data_ = np.flip(data_,axis=1)
        if seg_==16:
            dspec1 = data_
        else:
            dspec1 = np.concatenate((dspec1,data_),axis=1)
data_spec0 = np.concatenate((dspec1,dspec0),axis=0)
# Out:
# 1 Segment10
# 2 Segment11
# 3 Segment12
# 4 Segment13
# 5 Segment14
# 6 Segment15
# 7 Segment16
# 8 Segment17
# 9 Segment07
# 10 Segment06
# 11 Segment05
# 12 Segment04
# 13 Segment03
# 14 Segment02
# 15 Segment01
# 16 Segment00

# %%
#Just checking 
(data_spec0_test==data_spec0).all()
# Out:
# True

# %%
shape00 = data_spec0.shape
print(shape00)
# Out:
# (4000, 4072)

# %%
_ = plt.hist(data_spec0.ravel(),bins=100)
plt.yscale("log")

# %%
print(len(np.where(data_spec0.flatten()<0)[0]))
print(np.min(data_spec0.ravel()))
# Out:
# 0
# 11822

# %%
fig = plt.figure(figsize=(15,15))
ax=fig.add_subplot(111)
im = ax.imshow(data_spec0,cmap="gray",vmin=11000,vmax=18000)#,norm=LogNorm())
#im = ax.imshow(data_spec0,cmap="gray",norm=LogNorm())
fig.colorbar(im,ax=ax)

# %%
print(len(np.where(data_spec0.ravel()>100000)[0]))
# Out:
# 3784

# %%
spec = data_spec0[:,1670:1840]

spec_sum0 = np.sum(spec,axis=1)

# %%
fig = plt.figure(figsize=(10,10))
#plt.plot(np.linspace(0.,1100.,len(spec_sum)),spec_sum)
plt.plot(np.arange(len(spec_sum0)),spec_sum0)
#plt.xlim((300.,1100.))
plt.ylim((2.0e6,2.5e6))
plt.grid()

# %%
fig = plt.figure(figsize=(10,10))
#plt.plot(np.linspace(0.,1100.,len(spec_sum)),spec_sum)
plt.plot(np.arange(len(spec_sum0))*0.36,spec_sum0)
#plt.xlim((300.,1100.))
plt.ylim((2.0e6,2.5e6))
plt.grid()

# %%
f = fits.open('output_fits/deflatten_spectra_20220630_HD185975_FELH0600_20220608_bias_20220608/AT_O_20220630_000076_R00_S00_deflatten.fits')

# %%
for seg in range(1,num_segments+1):
    print(seg,f[seg].header['EXTNAME'])
    if seg<9:
        data_ = f[seg].data
        data_ = np.flip(data_,axis=0)
        data_ = np.flip(data_,axis=1)
        if seg==1:
            dspec0 = data_
        else:
            dspec0 = np.concatenate((dspec0,data_),axis=1)
    else:
        seg_ = num_segments+9-seg
        data_ = f[seg_].data
        data_ = np.flip(data_,axis=1)
        if seg_==16:
            dspec1 = data_
        else:
            dspec1 = np.concatenate((dspec1,data_),axis=1)
data_spec_all = np.concatenate((dspec1,dspec0),axis=0)
# Out:
# 1 Segment10
# 2 Segment11
# 3 Segment12
# 4 Segment13
# 5 Segment14
# 6 Segment15
# 7 Segment16
# 8 Segment17
# 9 Segment07
# 10 Segment06
# 11 Segment05
# 12 Segment04
# 13 Segment03
# 14 Segment02
# 15 Segment01
# 16 Segment00

# %%
print(data_spec_all.shape)
# Out:
# (4096, 4608)

# %%
'''
for seg in range(1,9):
    print(seg,f[seg].header['EXTNAME'])
    data_ = f[seg].data[:shape0[0]-voverscan,hprescan:shape0[1]-hoverscan]
    data_ = np.flip(data_,axis=0)
    data_ = np.flip(data_,axis=1)
    if seg==1:
        dspec0 = data_
    else:
        dspec0 = np.concatenate((dspec0,data_),axis=1)
for seg in range(9,num_segments+1):
    seg = num_segments+9-seg
    print(seg,f[seg].header['EXTNAME'])
    data_ = f[seg].data[:shape0[0]-voverscan,hprescan:shape0[1]-hoverscan]
    #data_ = np.flip(data_,axis=0)
    data_ = np.flip(data_,axis=1)
    if seg==16:
        dspec1 = data_
    else:
        dspec1 = np.concatenate((dspec1,data_),axis=1)
#data0spec = np.concatenate((dspec0,dspec1),axis=0)
data_spec = np.concatenate((dspec1,dspec0),axis=0)
'''
# Out:
# "\nfor seg in range(1,9):\n    print(seg,f[seg].header['EXTNAME'])\n    data_ = f[seg].data[:shape0[0]-voverscan,hprescan:shape0[1]-hoverscan]\n    data_ = np.flip(data_,axis=0)\n    data_ = np.flip(data_,axis=1)\n    if seg==1:\n        dspec0 = data_\n    else:\n        dspec0 = np.concatenate((dspec0,data_),axis=1)\nfor seg in range(9,num_segments+1):\n    seg = num_segments+9-seg\n    print(seg,f[seg].header['EXTNAME'])\n    data_ = f[seg].data[:shape0[0]-voverscan,hprescan:shape0[1]-hoverscan]\n    #data_ = np.flip(data_,axis=0)\n    data_ = np.flip(data_,axis=1)\n    if seg==16:\n        dspec1 = data_\n    else:\n        dspec1 = np.concatenate((dspec1,data_),axis=1)\n#data0spec = np.concatenate((dspec0,dspec1),axis=0)\ndata_spec = np.concatenate((dspec1,dspec0),axis=0)\n"

# %%
data_spec = plot_image(f)
# Out:
# 1 Segment10
# 2 Segment11
# 3 Segment12
# 4 Segment13
# 5 Segment14
# 6 Segment15
# 7 Segment16
# 8 Segment17
# 9 Segment07
# 10 Segment06
# 11 Segment05
# 12 Segment04
# 13 Segment03
# 14 Segment02
# 15 Segment01
# 16 Segment00

# %%
'''
for seg in range(1,9):
    print(seg,f[seg].header['EXTNAME'])
    data_ = f[seg].data[:shape0[0]-voverscan,hprescan:shape0[1]-hoverscan]
    data_ = np.flip(data_,axis=0)
    data_ = np.flip(data_,axis=1)
    if seg==1:
        dspec0 = data_
    else:
        dspec0 = np.concatenate((dspec0,data_),axis=1)
for seg in range(9,num_segments+1):
    seg = num_segments+9-seg
    print(seg,f[seg].header['EXTNAME'])
    data_ = f[seg].data[:shape0[0]-voverscan,hprescan:shape0[1]-hoverscan]
    #data_ = np.flip(data_,axis=0)
    data_ = np.flip(data_,axis=1)
    if seg==16:
        dspec1 = data_
    else:
        dspec1 = np.concatenate((dspec1,data_),axis=1)
#data0spec = np.concatenate((dspec0,dspec1),axis=0)
data_spec = np.concatenate((dspec1,dspec0),axis=0)
'''
# Out:
# "\nfor seg in range(1,9):\n    print(seg,f[seg].header['EXTNAME'])\n    data_ = f[seg].data[:shape0[0]-voverscan,hprescan:shape0[1]-hoverscan]\n    data_ = np.flip(data_,axis=0)\n    data_ = np.flip(data_,axis=1)\n    if seg==1:\n        dspec0 = data_\n    else:\n        dspec0 = np.concatenate((dspec0,data_),axis=1)\nfor seg in range(9,num_segments+1):\n    seg = num_segments+9-seg\n    print(seg,f[seg].header['EXTNAME'])\n    data_ = f[seg].data[:shape0[0]-voverscan,hprescan:shape0[1]-hoverscan]\n    #data_ = np.flip(data_,axis=0)\n    data_ = np.flip(data_,axis=1)\n    if seg==16:\n        dspec1 = data_\n    else:\n        dspec1 = np.concatenate((dspec1,data_),axis=1)\n#data0spec = np.concatenate((dspec0,dspec1),axis=0)\ndata_spec = np.concatenate((dspec1,dspec0),axis=0)\n"

# %%
shape = data_spec.shape
print(shape)
# Out:
# (4000, 4072)

# %%
_ = plt.hist(data_spec.flatten(),bins=100,range=(-2000,10))
plt.yscale("log")

# %%
np.min(data_spec.flatten())
# Out:
# -30247.069743121287

# %%
print(len(np.where(data_spec.flatten()<0)[0]))
# Out:
# 172063

# %%
print(len(np.where(data_spec.flatten()<0)[0])/len(data_spec.flatten()))
# Out:
# 0.010563789292730845

# %%
fig = plt.figure(figsize=(15,15))
ax=fig.add_subplot(111)
im = ax.imshow(data_spec,cmap="jet",vmin=-100,vmax=0)#,norm=LogNorm())
#im = ax.imshow(data_spec,cmap="gray",norm=LogNorm())
fig.colorbar(im,ax=ax)

# %%
print(data_spec.shape)
# Out:
# (4000, 4072)

# %%
transform = AsinhStretch() + PercentileInterval(99.)

# %%
scaledImage=transform(data_spec)

# %%
fig = plt.figure(figsize=(10,10))
ax=fig.add_subplot(111)
im = ax.imshow(scaledImage,origin="upper")
fig.colorbar(im,ax=ax)

# %%
fig = plt.figure(figsize=(10,10))
ax=fig.add_subplot(171)
im = ax.imshow(scaledImage[:,1540:1560],origin="upper")
fig.colorbar(im,ax=ax)

ax=fig.add_subplot(173)
im = ax.imshow(scaledImage[:,1400:2100],origin="upper")
fig.colorbar(im,ax=ax)

ax=fig.add_subplot(175)
im = ax.imshow(scaledImage[:,1860:1880],origin="upper")
fig.colorbar(im,ax=ax)

ax=fig.add_subplot(177)
im = ax.imshow(scaledImage[:,1670:1840],origin="upper")
fig.colorbar(im,ax=ax)

# %%
spec_df = data_spec[:,1670:1840]

spec_df_sum = np.sum(spec_df,axis=1)

# %%
fig = plt.figure(figsize=(10,10))
plt.plot(np.arange(len(spec_df_sum)),spec_df_sum)
#plt.xlim((300.,1100.))
plt.ylim((0.,0.175e6))
plt.grid()

# %%
fig = plt.figure(figsize=(10,10))
plt.plot(np.arange(len(spec_df_sum)),spec_df_sum)
plt.xlim((1500.,2500.))
plt.ylim((0.,0.175e6))
plt.grid()

# %%
fig = plt.figure(figsize=(10,10))
plt.plot(np.arange(len(spec_df_sum))*0.36,spec_df_sum)
plt.xlim((400.,1000.))
#plt.xlim((400.,480.))
plt.ylim((0.,0.175e6))
plt.grid()
